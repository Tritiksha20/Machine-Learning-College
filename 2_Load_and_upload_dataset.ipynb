# %% [markdown]
# <a href="https://colab.research.google.com/github/Tritiksha20/Machine-Learning-College/blob/main/2_Load_and_upload_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/iris (1).csv")
print("=" * 60)
print("First 5 rows of the dataset:")
print("=" * 60)
print(df.head())
# Out:
# ...
# First 5 rows of the dataset:
# ...
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target species
# 0       0  setosa
# 1       0  setosa
# 2       0  setosa
# 3       0  setosa
# 4       0  setosa

# %%
print("\n" + "=" * 60)
print("Last 5 rows of the dataset:")
print("=" * 60)
print(df.tail())
# Out:
# ...
# Last 5 rows of the dataset:
# ...
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target    species
# 145       2  virginica
# 146       2  virginica
# 147       2  virginica
# 148       2  virginica
# 149       2  virginica

# %%
print("\n" + "=" * 60)
print("Shape of the dataset (rows, columns):", df.shape)
print("=" * 60)
# Out:
# ...
# Shape of the dataset (rows, columns): (150, 6)
# ...

# %%
print("\n" + "=" * 60)
print("Column names:")
print("=" * 60)
print(list(df.columns))
# Out:
# ...
# Column names:
# ...
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)', 'target', 'species']

# %%
print("\n" + "=" * 60)
print("Data types of each column:")
print("=" * 60)
print(df.dtypes)
# Out:
# ...
# Data types of each column:
# ...
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                 int64
# species               object
# dtype: object

# %%
print("\n" + "=" * 60)
print("Random sample of 5 rows:")
print("=" * 60)
print(df.sample(5, random_state=1))
# Out:
# ...
# Random sample of 5 rows:
# ...
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 14                 5.8               4.0                1.2               0.2
# 98                 5.1               2.5                3.0               1.1
# 75                 6.6               3.0                4.4               1.4
# 16                 5.4               3.9                1.3               0.4
# 131                7.9               3.8                6.4               2.0
#
#      target     species
# 14        0      setosa
# 98        1  versicolor
# 75        1  versicolor
# 16        0      setosa
# 131       2   virginica

# %%
print("\n" + "=" * 60)
print("Unique species (target classes) in the dataset:")
print("=" * 60)
print(df['species'].unique())
# Out:
# ...
# Unique species (target classes) in the dataset:
# ...
# ['setosa' 'versicolor' 'virginica']
